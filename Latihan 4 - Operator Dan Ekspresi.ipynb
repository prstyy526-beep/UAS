# %% [markdown]
# # UAS Politeknik Krakatau

# %% [markdown]
# - Nama:
# - Kelas :
# - Dosen Pengampu : Yudistira Dwi Permana

# %% [markdown]
# ### Operator Dan Ekspresi

# %%
x = 11
y = 5

# %%
# Print hasil agar menjadi 2.2
print (x /y)
# Out:
# 2.2

# %% [markdown]
# penjelasan

# %%
# Print hasil relasi agar menghasilkan True
print(x > y)
# Out:
# True

# %% [markdown]
# penjelasan

# %%
# Print hasil logika agar menghasilkan False
print(x < y)
# Out:
# False

# %% [markdown]
# penjelasan
